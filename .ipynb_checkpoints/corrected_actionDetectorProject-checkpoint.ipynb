# y: 3.6200068
# z: 1.14791882
# visibility: 0.000157994655
# , x: 0.51415062
# y: 3.61080241
# z: 0.583762109
# visibility: 6.72471651e-005
# , x: 0.868020535
# y: 3.74905896
# z: 1.20814288
# visibility: 8.24298695e-005
# , x: 0.513944685
# y: 3.74584126
# z: 0.640975237
# visibility: 0.000113362221
# , x: 0.809175313
# y: 3.89663768
# z: 0.366552502
# visibility: 0.000409634551
# , x: 0.582952678
# y: 3.87543106
# z: -0.337272942
# visibility: 0.000325030589
# ]

# %%
pose = []
for res in results.pose_landmarks.landmark:
    test = np.array([res.x, res.y, res.z, res.visibility])
    pose.append(test)

# %%
pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)

# %%
face = np.zeros(1404)  # Default value in case no face landmarks are detected
if results.face_landmarks:
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten()

# %%
def extract_keypoints(results):
    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(33*4)
    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(468*3)
    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(21*3)
    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(21*3)
    return np.concatenate([pose, face, lh, rh])

# %%
result_test = extract_keypoints(results)

# %%
result_test
# Out:
# array([ 0.68746626,  0.61766261, -2.45348597, ...,  0.        ,
#         0.        ,  0.        ])

# %%
np.save('0', result_test)

# %%
np.load('0.npy')
# Out:
# array([ 0.68746626,  0.61766261, -2.45348597, ...,  0.        ,
#         0.        ,  0.        ])

# %%
# Path for exported data, numpy arrays
DATA_PATH = os.path.join('MP_Data') 

# Actions that we try to detect
actions = np.array(['hello', 'thanks', 'iloveyou'])

# Number of sequences per action
no_sequences = 5

# Videos are going to be 30 frames in length
sequence_length = 5

# Folder start index
start_folder = 5

# %%
for action in actions:
    action_path = os.path.join(DATA_PATH, action)

    # Ensure the action directory exists
    os.makedirs(action_path, exist_ok=True)

    # Get existing sequence folders and find the max index safely
    try:
        existing_folders = [int(folder) for folder in os.listdir(action_path) if folder.isdigit()]
        dirmax = max(existing_folders) if existing_folders else 0  # Set to 0 if empty
    except ValueError:
        dirmax = 0  # If conversion fails, assume no valid folders exist

    # Create new sequence folders
    for sequence in range(1, no_sequences + 1):
        new_folder = os.path.join(action_path, str(dirmax + sequence))
        os.makedirs(new_folder, exist_ok=True)  # Use exist_ok=True to avoid errors

# %%
# Initialize Video Capture
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    for action in actions:
        for sequence in range(start_folder, start_folder + no_sequences):
            for frame_num in range(sequence_length):

                # Read feed
                ret, frame = cap.read()

                # Check if frame is captured
                if not ret:
                    print("⚠️ Warning: Unable to read frame. Skipping...")
                    continue

                # Make detections
                image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)  # Convert to RGB
                results = holistic.process(image)

                # Convert back to BGR for OpenCV display
                image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

                # Draw landmarks
                if results.face_landmarks:
                    mp.solutions.drawing_utils.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION)
                if results.pose_landmarks:
                    mp.solutions.drawing_utils.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS)
                if results.left_hand_landmarks:
                    mp.solutions.drawing_utils.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS)
                if results.right_hand_landmarks:
                    mp.solutions.drawing_utils.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS)

                # NEW Apply wait logic
                if frame_num == 0:
                    cv2.putText(image, 'STARTING COLLECTION', (120, 200),
                                cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 4, cv2.LINE_AA)
                    cv2.putText(image, f'Collecting frames for {action} Video Number {sequence}', (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)
                    cv2.waitKey(5000)
                else:
                    cv2.putText(image, f'Collecting frames for {action} Video Number {sequence}', (15, 12),
                                cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 1, cv2.LINE_AA)
                    cv2.imshow('OpenCV Feed', image)

                # NEW Ensure directory exists before saving
                npy_folder = os.path.join(DATA_PATH, action, str(sequence))
                os.makedirs(npy_folder, exist_ok=True)  # ✅ Create missing directory
                
                # Extract keypoints function
                def extract_keypoints(results):
                    pose = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten() if results.pose_landmarks else np.zeros(132)
                    face = np.array([[res.x, res.y, res.z] for res in results.face_landmarks.landmark]).flatten() if results.face_landmarks else np.zeros(1404)
                    lh = np.array([[res.x, res.y, res.z] for res in results.left_hand_landmarks.landmark]).flatten() if results.left_hand_landmarks else np.zeros(63)
                    rh = np.array([[res.x, res.y, res.z] for res in results.right_hand_landmarks.landmark]).flatten() if results.right_hand_landmarks else np.zeros(63)
                    return np.concatenate([pose, face, lh, rh])

                # Export keypoints
                keypoints = extract_keypoints(results)
                npy_path = os.path.join(npy_folder, f"{frame_num}.npy")
                np.save(npy_path, keypoints)  # ✅ Save keypoints

                # Break gracefully
                if cv2.waitKey(10) & 0xFF == ord('q'):
                    break

# Release webcam and close OpenCV windows
cap.release()
cv2.destroyAllWindows()

# %%
cap.release()
cv2.destroyAllWindows()

# %%
#pREPROCESS DATA AND CREATE LABELS AND FEATURES

# %%
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical

# %%
label_map = {label:num for num, label in enumerate(actions)}

# %%
label_map
# Out:
# {'hello': 0, 'thanks': 1, 'iloveyou': 2}

# %%
sequences, labels = [], []

for action in actions:
    for sequence in np.array(os.listdir(os.path.join(DATA_PATH, action))).astype(int):
        window = []
        for frame_num in range(sequence_length):  # ✅ FIXED: Removed +1 to avoid extra frame
            npy_path = os.path.join(DATA_PATH, action, str(sequence), f"{frame_num}.npy")
            
            # ✅ FIX: Check if file exists before loading
            if os.path.exists(npy_path):
                res = np.load(npy_path)
                window.append(res)
            else:
                print(f"⚠️ Warning: Missing file {npy_path}, using zeros as placeholder.")
                window.append(np.zeros(1662))  # Adjust based on your keypoint size

        sequences.append(window)
        labels.append(label_map[action])  # Ensure label_map exists
# Out:
# ⚠️ Warning: Missing file MP_Data\hello\10\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\hello
4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\18\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\18\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\18\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\18\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\18\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\19\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\19\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\19\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\19\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\19\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\2\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\2\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\2\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\20\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\20\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\20\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\20\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\20\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\21\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\21\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\21\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\21\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\21\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\22\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\22\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\22\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\22\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\22\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\23\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\23\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\23\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\23\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\23\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\24\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\24\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\24\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\24\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\24\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\25\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\25\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\25\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\25\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\25\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\26\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\26\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\26\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\26\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\26\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\27\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\27\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\27\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\27\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\27\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\28\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\28\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\28\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\28\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\28\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\29\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\29\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\29\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\29\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\29\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\3\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\3\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\3\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\30\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\30\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\30\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\30\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\30\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\31\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\31\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\31\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\31\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\31\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\32\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\32\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\32\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\32\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\32\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\33\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\33\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\33\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\33\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\33\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\34\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\34\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\34\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\34\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\34\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\35\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\35\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\35\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\35\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\35\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\36\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\36\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\36\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\36\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\36\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\37\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\37\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\37\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\37\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\37\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\38\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\38\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\38\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\38\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\38\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\39\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\39\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\39\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\39\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\39\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\4\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\4\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\40\0.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\40\1.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\40\2.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\40\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\40\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\5\3.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\5\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\6\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\8\4.npy, using zeros as placeholder.
# ⚠️ Warning: Missing file MP_Data\iloveyou\9\4.npy, using zeros as placeholder.

# %%
np.array(sequences).shape
# Out:
# (120, 5, 1662)

# %%
np.array(labels).shape
# Out:
# (120,)

# %%
X = np.array(sequences)

# %%
X.shape
# Out:
# (120, 5, 1662)

# %%
y = to_categorical(labels).astype(int)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.05)

# %%
y_test.shape
# Out:
# (6, 3)

# %%
#Build and train neural network

# %%
from tensorflow.keras.models import Sequential #sequential flow of neural network creation
from tensorflow.keras.layers import LSTM, Dense #a component to build the neural network
from tensorflow.keras.callbacks import TensorBoard #

# %%
log_dir = os.path.join('Logs')
tb_callback = TensorBoard(log_dir=log_dir)

# %%
model = Sequential()
model.add(LSTM(64, return_sequences=True, activation='relu', input_shape=(30,1662)))
model.add(LSTM(128, return_sequences=True, activation='relu'))
model.add(LSTM(64, return_sequences=False, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(actions.shape[0], activation='softmax'))
# Out:
# C:\Users\Pranav\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# %%
model.fit(X_train, y_train, epochs=200, callbacks=[tb_callback])
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - categorical_accuracy: 0.3444 - loss: 1.0989
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3854 - loss: 1.1101
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3341 - loss: 1.0968
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3612 - loss: 1.0891
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3394 - loss: 1.0834
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4155 - loss: 1.0444
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3752 - loss: 1.0568
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3808 - loss: 1.0361
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.3923 - loss: 1.0357
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.3690 - loss: 1.0650
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4053 - loss: 1.0191
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.3756 - loss: 1.0350
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3785 - loss: 1.0288
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.3951 - loss: 1.0314
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4139 - loss: 1.0234
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.4472 - loss: 0.9922
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4120 - loss: 1.0062
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.3773 - loss: 1.0531
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.3944 - loss: 1.0253
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.3893 - loss: 1.0378
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4239 - loss: 1.0142
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0.3742 - loss: 1.0174
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3747 - loss: 1.0356
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4232 - loss: 1.0157
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.3721 - loss: 1.0290
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4360 - loss: 0.9983
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4053 - loss: 1.0071
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4423 - loss: 0.9967
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4251 - loss: 0.9757
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4323 - loss: 0.9599
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4698 - loss: 0.9611
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.3980 - loss: 0.9960
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4282 - loss: 0.9878
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4032 - loss: 0.9874
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - categorical_accuracy: 0
200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4744 - loss: 0.9769
# Epoch 174/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4237 - loss: 0.9948
# Epoch 175/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4550 - loss: 0.9474
# Epoch 176/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4359 - loss: 0.9757
# Epoch 177/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4693 - loss: 0.9559
# Epoch 178/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4553 - loss: 0.9514
# Epoch 179/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4481 - loss: 0.9565
# Epoch 180/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - categorical_accuracy: 0.4797 - loss: 0.9513
# Epoch 181/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - categorical_accuracy: 0.4386 - loss: 0.9738
# Epoch 182/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4680 - loss: 0.9469
# Epoch 183/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - categorical_accuracy: 0.4306 - loss: 0.9431
# Epoch 184/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4369 - loss: 0.9690
# Epoch 185/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4675 - loss: 0.9470
# Epoch 186/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4463 - loss: 0.9612
# Epoch 187/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4223 - loss: 0.9368
# Epoch 188/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - categorical_accuracy: 0.4112 - loss: 0.9530
# Epoch 189/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - categorical_accuracy: 0.4400 - loss: 0.9584
# Epoch 190/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4495 - loss: 0.9373
# Epoch 191/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.4379 - loss: 0.9255
# Epoch 192/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.3973 - loss: 0.9434
# Epoch 193/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - categorical_accuracy: 0.4088 - loss: 0.9675
# Epoch 194/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - categorical_accuracy: 0.3952 - loss: 0.9679
# Epoch 195/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - categorical_accuracy: 0.4435 - loss: 0.9324
# Epoch 196/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.4408 - loss: 0.9313
# Epoch 197/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4198 - loss: 0.9471
# Epoch 198/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4362 - loss: 0.9702
# Epoch 199/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - categorical_accuracy: 0.4494 - loss: 0.9276
# Epoch 200/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - categorical_accuracy: 0.4974 - loss: 0.9005

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                       │ (None, 30, 64)              │         442,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_13 (LSTM)                       │ (None, 30, 128)             │          98,816 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_14 (LSTM)                       │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 64)                  │           4,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 3)                   │              99 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,790,027 (6.83 MB)
#  Trainable params: 596,675 (2.28 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 1,193,352 (4.55 MB)

# %%
#MAke predictions

# %%
res = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step

# %%
if len(res) > 4:
    predicted_action = actions[np.argmax(res[4])]
else:
    predicted_action = actions[np.argmax(res[0])]  

if len(y_test) > 4:
    actual_action = actions[np.argmax(y_test[4])]
else:
    actual_action = actions[np.argmax(y_test[0])]

print("Predicted Action:", predicted_action)
print("Actual Action:", actual_action)
# Out:
# Predicted Action: thanks
# Actual Action: iloveyou

# %%
model.save('action.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# del model

# %%
model.load_weights('action.h5')

# %%
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score

# %%
yhat = model.predict(X_test)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step

# %%
ytrue = np.argmax(y_test, axis=1).tolist()
yhat = np.argmax(yhat, axis=1).tolist()

# %%
multilabel_confusion_matrix(ytrue, yhat)
# Out:
# array([[[3, 0],
#         [3, 0]],
#
#        [[0, 5],
#         [0, 1]],
#
#        [[4, 0],
#         [2, 0]]], dtype=int64)

# %%
accuracy_score(ytrue, yhat)
# Out:
# 0.16666666666666666

# %%
from scipy import stats

# %%
colors = [(245,117,16), (117,245,16), (16,117,245)]# Generate one color per action

def prob_viz(res, actions, input_frame, colors):
    output_frame = input_frame.copy()

    # Debugging prints
    print(f"res length: {len(res)}, actions length: {len(actions)}, colors length: {len(colors)}")

    for num, prob in enumerate(res):
        if num >= len(actions) or num >= len(colors):  # Prevent index error
            print(f"Skipping index {num}, out of range")
            continue
            
        cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
        cv2.putText(output_frame, actions[num], (0, 85 + num * 40), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

    return output_frame

# %%
plt.figure(figsize=(18,18))
plt.imshow(prob_viz(res, actions, image, colors))
# Out:
# res length: 6, actions length: 3, colors length: 3
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[280], line 2
#       1 plt.figure(figsize=(18,18))
# ----> 2 plt.imshow(prob_viz(res, actions, image, colors))
#
# Cell In[279], line 14, in prob_viz(res, actions, input_frame, colors)
#      11         print(f"Skipping index {num}, out of range")
#      12         continue
# ---> 14     cv2.rectangle(output_frame, (0,60+num*40), (int(prob*100), 90+num*40), colors[num], -1)
#      15     cv2.putText(output_frame, actions[num], (0, 85 + num * 40),
#      16                 cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
#      18 return output_frame
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
# 1. New detection variables
sequence = []
sentence = []
predictions = []
threshold = 0.5

cap = cv2.VideoCapture(0)

# Set mediapipe model 
with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
    while cap.isOpened():
        # Read feed
        ret, frame = cap.read()

        # Make detections
        image, results = mediapipe_detection(frame, holistic)
        print(results)
        
        # Draw landmarks
        draw_styled_landmarks(image, results)
        
        # 2. Prediction logic
        keypoints = extract_keypoints(results)
        sequence.append(keypoints)
        sequence = sequence[-30:]
        
        if len(sequence) == 30:
            res = model.predict(np.expand_dims(sequence, axis=0))[0]
            print(actions[np.argmax(res)])
            predictions.append(np.argmax(res))
            
            # 3. Viz logic
            if len(predictions) >= 10 and np.unique(predictions[-10:])[0] == np.argmax(res): 
                if res[np.argmax(res)] > threshold: 
                    if len(sentence) > 0:
                        if actions[np.argmax(res)] != sentence[-1]:
                            sentence.append(actions[np.argmax(res)])
                    else:
                        sentence.append(actions[np.argmax(res)])

            if len(sentence) > 5:
                sentence = sentence[-5:]

            # Viz probabilities
            image = prob_viz(res, actions, image, colors)
        
        cv2.rectangle(image, (0, 0), (640, 40), (245, 117, 16), -1)
        cv2.putText(image, ' '.join(sentence), (3, 30), 
                    cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)
        
        # Show to screen
        cv2.imshow('OpenCV Feed', image)

        # Break gracefully
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()
# Out:
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
# <class 'mediapipe.python.solution_base.SolutionOutputs'>
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# iloveyou
# res length: 3, actions length: 3, colors length: 3
